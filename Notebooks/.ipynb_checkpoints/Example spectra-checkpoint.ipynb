# %% [markdown]
# # Example spectra comparison

# %% [markdown]
# Note: I intended to do this with Excel, but it was not excel-ent for doing that. I'll go Matplotlib instead.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("vnir-wood-spectra.csv").T
df = df.set_axis(df.iloc[0,:], axis=1)
df = df.iloc[1:,:]
df
# Out:
# Row OnlyWood LittleDecay OnlyWood MuchDecay KreosoteWood LittleDecay  \
# 412             0.131973           0.089863                 0.132957
# 415             0.123068           0.084546                  0.12355
# 418             0.114274           0.079109                 0.114877
# 420             0.107317           0.074519                 0.107479
# 423             0.100636           0.070266                 0.100628
# ..                   ...                ...                      ...
# 978             0.613851           0.440873                 0.665121
# 981             0.614282           0.441926                 0.665561
# 983             0.614699           0.442665                 0.666475
# 986             0.615531           0.443654                 0.667732
# 989             0.616354           0.444783                  0.66874
#
# Row KreosoteWood MuchDecay     water
# 412               0.091457  0.000046
# 415               0.085594  0.000044
# 418               0.079203  0.000044
# 420               0.074888  0.000046
# 423               0.070373  0.000048
# ..                     ...       ...
# 978               0.457095  0.507711
# 981               0.458005   0.50158
# 983               0.458902  0.493704
# 986               0.459913  0.484055
# 989               0.460866  0.472593
#
# [200 rows x 5 columns]

# %%
sns.lineplot(df)
plt.xticks(range(np.min(plt.xticks()[0]), np.max(plt.xticks()[0]), 20));
